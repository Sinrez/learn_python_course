# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinrez/learn_python_course/blob/master/learn_python_data_sci_track.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openpyxl
# https://data.mos.ru/datasets/752
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.9/dist-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.9/dist-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd
import numpy as np

# %%
import openpyxl

streets = {}

wb_obj = openpyxl.load_workbook('/content/data-398-2023-02-27.xlsx') 
sheet_obj = wb_obj.active 

cell_obj = sheet_obj.cell(row = 1, column = 1) 
print(cell_obj.value)

row = sheet_obj.max_row
column = sheet_obj.max_column
  
print("Total Rows:", row)
print("Total Columns:", column)

cell_obj = sheet_obj['A1': 'B6']
  
# Print value of cell object 
# using the value attribute 
for cell1, cell2 in cell_obj:
    print(cell1.value, cell2.value)
# Out:
# /usr/local/lib/python3.9/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ID
# Total Rows: 11368
# Total Columns: 31
# ID Name
# Локальный идентификатор Наименование
# 7 «Дербеневская наб.», 3-й Дербеневский переулок (от центра) (7)
# 11 «Наб. Тараса Шевченко», набережная Тараса Шевченко (в центр) (11)
# 27 «Кардиоцентр», 3-я Черепковская улица (в центр) (27)
# 35 «Керамический пр.», Дубнинская улица (в центр) (35)

# %%
  # print(cell_obj)
for cell1, cell2  in cell_obj:
        if cell2.value in streets:
            streets[cell2.value] += 1
        else:
            streets[cell2.value] = 1
print(streets)
# Out:
# {'Name': 1, 'Наименование': 1, '«Дербеневская наб.», 3-й Дербеневский переулок (от центра) (7)': 1, '«Наб. Тараса Шевченко», набережная Тараса Шевченко (в центр) (11)': 1, '«Кардиоцентр», 3-я Черепковская улица (в центр) (27)': 1, '«Керамический пр.», Дубнинская улица (в центр) (35)': 1}

# %%
import pandas as pd
my_series = pd.Series([4, 7, -5, 3, -1])
my_series
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# 4   -1
# dtype: int64

# %%
my_series[my_series > 0]
# Out:
# 0    4
# 1    7
# 3    3
# dtype: int64

# %%
np.exp(my_series)
# Out:
# 0      54.598150
# 1    1096.633158
# 2       0.006738
# 3      20.085537
# 4       0.367879
# dtype: float64

# %%
import pandas as pd
df = pd.DataFrame({
    'name': ['Маша', 'Вася', 'Эдуард'], 
    'age': [25, 8, 48], 
    'job': ['Программист', 'Школьник', 'Big Boss'],
    'salary': [100, 10, 200]
})
df
# Out:
#      name  age          job  salary
# 0    Маша   25  Программист     100
# 1    Вася    8     Школьник      10
# 2  Эдуард   48     Big Boss     200

# %%
df.loc[:0]
# Out:
#    name  age          job  salary
# 0  Маша   25  Программист     100

# %%
df['name']
df[df['age'] > 18]
df.T
# Out:
#                   0         1         2
# name           Маша      Вася    Эдуард
# age              25         8        48
# job     Программист  Школьник  Big Boss
# salary          100        10       200

# %%
df.iloc[:1]
# Out:
#    name  age          job  salary
# 0  Маша   25  Программист     100

# %%
df.iloc[:1]
# Out:
#    name  age          job  salary
# 0  Маша   25  Программист     100

# %%
import pandas as pd
pd.read_excel(io='/content/data-398-2023-02-27.xlsx', engine='openpyxl')
# Out:
# /usr/local/lib/python3.9/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                             ID  \
# 0      Локальный идентификатор
# 1                            7
# 2                           11
# 3                           27
# 4                           35
# ...                        ...
# 11362                  1009905
# 11363                  1009906
# 11364                  1010496
# 11365                    21133
# 11366                    21235
#
#                                                     Name   Longitude_WGS84  \
# 0                                           Наименование  Долгота в WGS-84
# 1      «Дербеневская наб.», 3-й Дербеневский переулок...        37.6551636
# 2      «Наб. Тараса Шевченко», набережная Тараса Шевч...       37.57227413
# 3      «Кардиоцентр», 3-я Черепковская улица (в центр...       37.37550932
# 4      «Керамический пр.», Дубнинская улица (в центр)...       37.55724554
# ...                                                  ...               ...
# 11362  «ЖК «Домашний», Проектируемый проезд № 6276 (в...       37.70341194
# 11363  «Курьяновская наб.», Проектируемый проезд № 62...        37.7002543
# 11364  «Северный - 9-й мкр.», улица Академика Алихано...       37.53964378
# 11365  «МЦД Царицыно», Севанская улица (от центра) (2...        37.6662753
# 11366  «Лефортовский рынок», Авиамоторная улица (от ц...       37.71583694
#
#         Latitude_WGS84                                  AdmArea  \
# 0      Широта в WGS-84                   Административный округ
# 1          55.72566817             Южный административный округ
# 2          55.74967848          Западный административный округ
# 3           55.7572642          Западный административный округ
# 4          55.89460802          Северный административный округ
# ...                ...                                      ...
# 11362      55.64720485     Юго-Восточный административный округ
# 11363      55.64414191     Юго-Восточный административный округ
# 11364      55.92089904  Северо-Восточный административный округ
# 11365      55.61859411             Южный административный округ
# 11366       55.7551631     Юго-Восточный административный округ
#
#                        District                    RouteNumbers  \
# 0                         Район                        Маршруты
# 1             Даниловский район                     А913; АС932
# 2            район Дорогомилово                      А205; А622
# 3                 район Кунцево                А660; А798; А816
# 4      район Восточное Дегунино   А167; А179; А499; А677; А677к
# ...                         ...                             ...
# 11362             район Марьино          А541; А762; А957; Ат74
# 11363             район Марьино          А541; А762; А957; Ат74
# 11364            район Северный     А685; А746; А836; А843; Ан9
# 11365            район Царицыно  А921; Ам87; Ан13; Ас823; Ас869
# 11366           район Лефортово                      Тм32; Тм46
#
#                 StationName    Direction           Pavilion  ...  \
# 0        Название остановки  Направление  Наличие павильона  ...
# 1         Дербеневская наб.    от центра                 да  ...
# 2      Наб. Тараса Шевченко      в центр                нет  ...
# 3               Кардиоцентр      в центр                 да  ...
# 4          Керамический пр.      в центр                 да  ...
# ...                     ...          ...                ...  ...
# 11362         ЖК «Домашний»      в центр                нет  ...
# 11363     Курьяновская наб.      в центр                нет  ...
# 11364   Северный - 9-й мкр.      в центр                нет  ...
# 11365          МЦД Царицыно    от центра                нет  ...
# 11366    Лефортовский рынок    от центра                нет  ...
#
#        RouteNumbers_en  StationName_en  Direction_en  Pavilion_en  \
# 0      RouteNumbers_en  StationName_en  Direction_en  Pavilion_en
# 1                  NaN             NaN           NaN          NaN
# 2                  NaN             NaN           NaN          NaN
# 3                  NaN             NaN           NaN          NaN
# 4                  NaN             NaN           NaN          NaN
# ...                ...             ...           ...          ...
# 11362              NaN             NaN           NaN          NaN
# 11363              NaN             NaN           NaN          NaN
# 11364              NaN             NaN           NaN          NaN
# 11365              NaN             NaN           NaN          NaN
# 11366              NaN             NaN           NaN          NaN
#
#        OperatingOrgName_en  EntryState_en  PlaceDescription_en  Works_en  \
# 0      OperatingOrgName_en  EntryState_en  PlaceDescription_en  Works_en
# 1                      NaN            NaN                  NaN       NaN
# 2                      NaN            NaN                  NaN       NaN
# 3                      NaN            NaN                  NaN       NaN
# 4                      NaN            NaN                  NaN       NaN
# ...                    ...            ...                  ...       ...
# 11362                  NaN            NaN                  NaN       NaN
# 11363                  NaN            NaN                  NaN       NaN
# 11364                  NaN            NaN                  NaN       NaN
# 11365                  NaN            NaN                  NaN       NaN
# 11366                  NaN            NaN                  NaN       NaN
#
#                                           geodata_center  geoarea
# 0                                         geodata_center  geoarea
# 1      {"coordinates":[37.6551636,55.72566817],"type"...      NaN
# 2      {"coordinates":[37.57227413,55.74967848],"type...      NaN
# 3      {"coordinates":[37.37550932,55.7572642],"type"...      NaN
# 4      {"coordinates":[37.55724554,55.89460802],"type...      NaN
# ...                                                  ...      ...
# 11362  {"coordinates":[37.70341194,55.64720485],"type...      NaN
# 11363  {"coordinates":[37.7002543,55.64414191],"type"...      NaN
# 11364  {"coordinates":[37.53964378,55.92089904],"type...      NaN
# 11365  {"coordinates":[37.6662753,55.61859411],"type"...      NaN
# 11366  {"coordinates":[37.71583694,55.7551631],"type"...      NaN
#
# [11367 rows x 31 columns]
